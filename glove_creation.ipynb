# %%
import nltk

# %%
import re

paragraph = """Mumtaz Mahal, an inseparable companion of Shah Jahan, died in 1631, while giving birth to their 14th child. It was in the memory of his beloved wife that Shah Jahan built a magnificent monument as a tribute to her, which we today know as the "Taj Mahal". The construction of Taj Mahal started in the year 1631. Masons, stonecutters, inlayers, carvers, painters, calligraphers, dome-builders and other artisans were requisitioned from the whole of the empire and also from Central Asia and Iran, and it took approximately 22 years to build what we see today. An epitome of love, it made use of the services of 22,000 laborers and 1,000 elephants. The monument was built entirely out of white marble, which was brought in from all over India and central Asia. After an expenditure of approximately 32 million rupees, Taj Mahal was finally completed in the year 1653.

It was soon after the completion of Taj Mahal that Shah Jahan was deposed by his own son Aurangzeb and was put under house arrest at nearby Agra Fort. Shah Jahan, himself also, lies entombed in this mausoleum along with his wife. Moving further down the history, it was at the end of the 19th century that British Viceroy Lord Curzon ordered a sweeping restoration project, which was completed in 1908, as a measure to restore what was lost during the Indian rebellion of 1857: Taj being blemished by British soldiers and government officials who also deprived the monument of its immaculate beauty by chiseling out precious stones and lapis lazuli from its walls. Also, the British style lawns that we see today adding on to the beauty of Taj were remodeled around the same time. Despite prevailing controversies, past and present threats from Indo-Pak war and environmental pollution, this epitome of love continuous to shine and attract people from all over the world."""

# %%
paragraph
# Out:
# 'Mumtaz Mahal, an inseparable companion of Shah Jahan, died in 1631, while giving birth to their 14th child. It was in the memory of his beloved wife that Shah Jahan built a magnificent monument as a tribute to her, which we today know as the "Taj Mahal". The construction of Taj Mahal started in the year 1631. Masons, stonecutters, inlayers, carvers, painters, calligraphers, dome-builders and other artisans were requisitioned from the whole of the empire and also from Central Asia and Iran, and it took approximately 22 years to build what we see today. An epitome of love, it made use of the services of 22,000 laborers and 1,000 elephants. The monument was built entirely out of white marble, which was brought in from all over India and central Asia. After an expenditure of approximately 32 million rupees, Taj Mahal was finally completed in the year 1653.\n\nIt was soon after the completion of Taj Mahal that Shah Jahan was deposed by his own son Aurangzeb and was put under house arrest at nearby Agra Fort. Shah Jahan, himself also, lies entombed in this mausoleum along with his wife. Moving further down the history, it was at the end of the 19th century that British Viceroy Lord Curzon ordered a sweeping restoration project, which was completed in 1908, as a measure to restore what was lost during the Indian rebellion of 1857: Taj being blemished by British soldiers and government officials who also deprived the monument of its immaculate beauty by chiseling out precious stones and lapis lazuli from its walls. Also, the British style lawns that we see today adding on to the beauty of Taj were remodeled around the same time. Despite prevailing controversies, past and present threats from Indo-Pak war and environmental pollution, this epitome of love continuous to shine and attract people from all over the world.'

# %%
#preprocessing the data
text = re.sub(r'\[[0-9]*\]',' ',paragraph) 
text = re.sub(r'\s+',' ',text) #it removes unnecessary spaces
text = text.lower() #it converts lower letters
text = re.sub(r'\d', ' ',text) 
text = re.sub(r'\s+', ' ',text)
#text = re.sub('[^a-zA-Z]', ' ',text)

# %%
text
# Out:
# 'mumtaz mahal, an inseparable companion of shah jahan, died in , while giving birth to their th child. it was in the memory of his beloved wife that shah jahan built a magnificent monument as a tribute to her, which we today know as the "taj mahal". the construction of taj mahal started in the year . masons, stonecutters, inlayers, carvers, painters, calligraphers, dome-builders and other artisans were requisitioned from the whole of the empire and also from central asia and iran, and it took approximately years to build what we see today. an epitome of love, it made use of the services of , laborers and , elephants. the monument was built entirely out of white marble, which was brought in from all over india and central asia. after an expenditure of approximately million rupees, taj mahal was finally completed in the year . it was soon after the completion of taj mahal that shah jahan was deposed by his own son aurangzeb and was put under house arrest at nearby agra fort. shah jahan, himself also, lies entombed in this mausoleum along with his wife. moving further down the history, it was at the end of the th century that british viceroy lord curzon ordered a sweeping restoration project, which was completed in , as a measure to restore what was lost during the indian rebellion of : taj being blemished by british soldiers and government officials who also deprived the monument of its immaculate beauty by chiseling out precious stones and lapis lazuli from its walls. also, the british style lawns that we see today adding on to the beauty of taj were remodeled around the same time. despite prevailing controversies, past and present threats from indo-pak war and environmental pollution, this epitome of love continuous to shine and attract people from all over the world.'

# %%
# preparing the dataset
sentences = nltk.sent_tokenize(text) #it is split into sentences

# %%
sentences
# Out:
# ['mumtaz mahal, an inseparable companion of shah jahan, died in , while giving birth to their th child.',
#  'it was in the memory of his beloved wife that shah jahan built a magnificent monument as a tribute to her, which we today know as the "taj mahal".',
#  'the construction of taj mahal started in the year .',
#  'masons, stonecutters, inlayers, carvers, painters, calligraphers, dome-builders and other artisans were requisitioned from the whole of the empire and also from central asia and iran, and it took approximately years to build what we see today.',
#  'an epitome of love, it made use of the services of , laborers and , elephants.',
#  'the monument was built entirely out of white marble, which was brought in from all over india and central asia.',
#  'after an expenditure of approximately million rupees, taj mahal was finally completed in the year .',
#  'it was soon after the completion of taj mahal that shah jahan was deposed by his own son aurangzeb and was put under house arrest at nearby agra fort.',
#  'shah jahan, himself also, lies entombed in this mausoleum along with his wife.',
#  'moving further down the history, it was at the end of the th century that british viceroy lord curzon ordered a sweeping restoration project, which was completed in , as a measure to restore what was lost during the indian rebellion of : taj being blemished by british soldiers and government officials who also deprived the monument of its immaculate beauty by chiseling out precious stones and lapis lazuli from its walls.',
#  'also, the british style lawns that we see today adding on to the beauty of taj were remodeled around the same time.',
#  'despite prevailing controversies, past and present threats from indo-pak war and environmental pollution, this epitome of love continuous to shine and attract people from all over the world.']

# %%
len(sentences)
# Out:
# 12

# %%
#sentences are split into words
sentences = [nltk.word_tokenize(sentence) for sentence in sentences]

# %%
sentences
# Out:
# [['mumtaz',
#   'mahal',
#   ',',
#   'an',
#   'inseparable',
#   'companion',
#   'of',
#   'shah',
#   'jahan',
#   ',',
#   'died',
#   'in',
#   ',',
#   'while',
#   'giving',
#   'birth',
#   'to',
#   'their',
#   'th',
#   'child',
#   '.'],
#  ['it',
#   'was',
#   'in',
#   'the',
#   'memory',
#   'of',
#   'his',
#   'beloved',
#   'wife',
#   'that',
#   'shah',
#   'jahan',
#   'built',
#   'a',
#   'magnificent',
#   'monument',
#   'as',
#   'a',
#   'tribute',
#   'to',
#   'her',
#   ',',
#   'which',
#   'we',
#   'today',
#   'know',
#   'as',
#   'the',
#   '``',
#   'taj',
#   'mahal',
#   "''",
#   '.'],
#  ['the',
#   'construction',
#   'of',
#   'taj',
#   'mahal',
#   'started',
#   'in',
#   'the',
#   'year',
#   '.'],
#  ['masons',
#   ',',
#   'stonecutters',
#   ',',
#   'inlayers',
#   ',',
#   'carvers',
#   ',',
#   'painters',
#   ',',
#   'calligraphers',
#   ',',
#   'dome-builders',
#   'and',
#   'other',
#   'artisans',
#   'were',
#   'requisitioned',
#   'from',
#   'the',
#   'whole',
#   'of',
#   'the',
#   'empire',
#   'and',
#   'also',
#   'from',
#   'central',
#   'asia',
#   'and',
#   'iran',
#   ',',
#   'and',
#   'it',
#   'took',
#   'approximately',
#   'years',
#   'to',
#   'build',
#   'what',
#   'we',
#   'see',
#   'today',
#   '.'],
#  ['an',
#   'epitome',
#   'of',
#   'love',
#   ',',
#   'it',
#   'made',
#   'use',
#   'of',
#   'the',
#   'services',
#   'of',
#   ',',
#   'laborers',
#   'and',
#   ',',
#   'elephants',
#   '.'],
#  ['the',
#   'monument',
#   'was',
#   'built',
#   'entirely',
#   'out',
#   'of',
#   'white',
#   'marble',
#   ',',
#   'which',
#   'was',
#   'brought',
#   'in',
#   'from',
#   'all',
#   'over',
#   'india',
#   'and',
#   'central',
#   'asia',
#   '.'],
#  ['after',
#   'an',
#   'expenditure',
#   'of',
#   'approximately',
#   'million',
#   'rupees',
#   ',',
#   'taj',
#   'mahal',
#   'was',
#   'finally',
#   'completed',
#   'in',
#   'the',
#   'year',
#   '.'],
#  ['it',
#   'was',
#   'soon',
#   'after',
#   'the',
#   'completion',
#   'of',
#   'taj',
#   'mahal',
#   'that',
#   'shah',
#   'jahan',
#   'was',
#   'deposed',
#   'by',
#   'his',
#   'own',
#   'son',
#   'aurangzeb',
#   'and',
#   'was',
#   'put',
#   'under',
#   'house',
#   'arrest',
#   'at',
#   'nearby',
#   'agra',
#   'fort',
#   '.'],
#  ['shah',
#   'jahan',
#   ',',
#   'himself',
#   'also',
#   ',',
#   'lies',
#   'entombed',
#   'in',
#   'this',
#   'mausoleum',
#   'along',
#   'with',
#   'his',
#   'wife',
#   '.'],
#  ['moving',
#   'further',
#   'down',
#   'the',
#   'history',
#   ',',
#   'it',
#   'was',
#   'at',
#   'the',
#   'end',
#   'of',
#   'the',
#   'th',
#   'century',
#   'that',
#   'british',
#   'viceroy',
#   'lord',
#   'curzon',
#   'ordered',
#   'a',
#   'sweeping',
#   'restoration',
#   'project',
#   ',',
#   'which',
#   'was',
#   'completed',
#   'in',
#   ',',
#   'as',
#   'a',
#   'measure',
#   'to',
#   'restore',
#   'what',
#   'was',
#   'lost',
#   'during',
#   'the',
#   'indian',
#   'rebellion',
#   'of',
#   ':',
#   'taj',
#   'being',
#   'blemished',
#   'by',
#   'british',
#   'soldiers',
#   'and',
#   'government',
#   'officials',
#   'who',
#   'also',
#   'deprived',
#   'the',
#   'monument',
#   'of',
#   'its',
#   'immaculate',
#   'beauty',
#   'by',
#   'chiseling',
#   'out',
#   'precious',
#   'stones',
#   'and',
#   'lapis',
#   'lazuli',
#   'from',
#   'its',
#   'walls',
#   '.'],
#  ['also',
#   ',',
#   'the',
#   'british',
#   'style',
#   'lawns',
#   'that',
#   'we',
#   'see',
#   'today',
#   'adding',
#   'on',
#   'to',
#   'the',
#   'beauty',
#   'of',
#   'taj',
#   'were',
#   'remodeled',
#   'around',
#   'the',
#   'same',
#   'time',
#   '.'],
#  ['despite',
#   'prevailing',
#   'controversies',
#   ',',
#   'past',
#   'and',
#   'present',
#   'threats',
#   'from',
#   'indo-pak',
#   'war',
#   'and',
#   'environmental',
#   'pollution',
#   ',',
#   'this',
#   'epitome',
#   'of',
#   'love',
#   'continuous',
#   'to',
#   'shine',
#   'and',
#   'attract',
#   'people',
#   'from',
#   'all',
#   'over',
#   'the',
#   'world',
#   '.']]

# %%
#remove the stopwords
from nltk.corpus import stopwords
for i in range(len(sentences)):
    sentences[i] = [word for word in sentences[i] if word not in stopwords.words('english')]

# %%
sentences
# Out:
# [['mumtaz',
#   'mahal',
#   ',',
#   'inseparable',
#   'companion',
#   'shah',
#   'jahan',
#   ',',
#   'died',
#   ',',
#   'giving',
#   'birth',
#   'th',
#   'child',
#   '.'],
#  ['memory',
#   'beloved',
#   'wife',
#   'shah',
#   'jahan',
#   'built',
#   'magnificent',
#   'monument',
#   'tribute',
#   ',',
#   'today',
#   'know',
#   '``',
#   'taj',
#   'mahal',
#   "''",
#   '.'],
#  ['construction', 'taj', 'mahal', 'started', 'year', '.'],
#  ['masons',
#   ',',
#   'stonecutters',
#   ',',
#   'inlayers',
#   ',',
#   'carvers',
#   ',',
#   'painters',
#   ',',
#   'calligraphers',
#   ',',
#   'dome-builders',
#   'artisans',
#   'requisitioned',
#   'whole',
#   'empire',
#   'also',
#   'central',
#   'asia',
#   'iran',
#   ',',
#   'took',
#   'approximately',
#   'years',
#   'build',
#   'see',
#   'today',
#   '.'],
#  ['epitome',
#   'love',
#   ',',
#   'made',
#   'use',
#   'services',
#   ',',
#   'laborers',
#   ',',
#   'elephants',
#   '.'],
#  ['monument',
#   'built',
#   'entirely',
#   'white',
#   'marble',
#   ',',
#   'brought',
#   'india',
#   'central',
#   'asia',
#   '.'],
#  ['expenditure',
#   'approximately',
#   'million',
#   'rupees',
#   ',',
#   'taj',
#   'mahal',
#   'finally',
#   'completed',
#   'year',
#   '.'],
#  ['soon',
#   'completion',
#   'taj',
#   'mahal',
#   'shah',
#   'jahan',
#   'deposed',
#   'son',
#   'aurangzeb',
#   'put',
#   'house',
#   'arrest',
#   'nearby',
#   'agra',
#   'fort',
#   '.'],
#  ['shah',
#   'jahan',
#   ',',
#   'also',
#   ',',
#   'lies',
#   'entombed',
#   'mausoleum',
#   'along',
#   'wife',
#   '.'],
#  ['moving',
#   'history',
#   ',',
#   'end',
#   'th',
#   'century',
#   'british',
#   'viceroy',
#   'lord',
#   'curzon',
#   'ordered',
#   'sweeping',
#   'restoration',
#   'project',
#   ',',
#   'completed',
#   ',',
#   'measure',
#   'restore',
#   'lost',
#   'indian',
#   'rebellion',
#   ':',
#   'taj',
#   'blemished',
#   'british',
#   'soldiers',
#   'government',
#   'officials',
#   'also',
#   'deprived',
#   'monument',
#   'immaculate',
#   'beauty',
#   'chiseling',
#   'precious',
#   'stones',
#   'lapis',
#   'lazuli',
#   'walls',
#   '.'],
#  ['also',
#   ',',
#   'british',
#   'style',
#   'lawns',
#   'see',
#   'today',
#   'adding',
#   'beauty',
#   'taj',
#   'remodeled',
#   'around',
#   'time',
#   '.'],
#  ['despite',
#   'prevailing',
#   'controversies',
#   ',',
#   'past',
#   'present',
#   'threats',
#   'indo-pak',
#   'war',
#   'environmental',
#   'pollution',
#   ',',
#   'epitome',
#   'love',
#   'continuous',
#   'shine',
#   'attract',
#   'people',
#   'world',
#   '.']]

# %%
stopwords.words('english')
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
from gensim.models import Word2Vec

# %%
#training the word2vec model
model = Word2Vec(sentences, min_count=1) 
#here we use 'min_count=1': if that word is present in lessthan 1.and that word is skip and continue to next word

# %%
words = model.wv.vocab  #find out the vocabulary in the model

# %%
words
# Out:
# {'mumtaz': <gensim.models.keyedvectors.Vocab at 0x201510af9c8>,
#  'mahal': <gensim.models.keyedvectors.Vocab at 0x201510afe48>,
#  ',': <gensim.models.keyedvectors.Vocab at 0x201510aff88>,
#  'inseparable': <gensim.models.keyedvectors.Vocab at 0x201510afec8>,
#  'companion': <gensim.models.keyedvectors.Vocab at 0x201510affc8>,
#  'shah': <gensim.models.keyedvectors.Vocab at 0x201510af288>,
#  'jahan': <gensim.models.keyedvectors.Vocab at 0x201510af048>,
#  'died': <gensim.models.keyedvectors.Vocab at 0x201510af3c8>,
#  'giving': <gensim.models.keyedvectors.Vocab at 0x201510aff48>,
#  'birth': <gensim.models.keyedvectors.Vocab at 0x201510af308>,
#  'th': <gensim.models.keyedvectors.Vocab at 0x201510afa88>,
#  'child': <gensim.models.keyedvectors.Vocab at 0x201510afa48>,
#  '.': <gensim.models.keyedvectors.Vocab at 0x201510ab048>,
#  'memory': <gensim.models.keyedvectors.Vocab at 0x201510ab088>,
#  'beloved': <gensim.models.keyedvectors.Vocab at 0x201510ab0c8>,
#  'wife': <gensim.models.keyedvectors.Vocab at 0x201510ab108>,
#  'built': <gensim.models.keyedvectors.Vocab at 0x201510ab148>,
#  'magnificent': <gensim.models.keyedvectors.Vocab at 0x201510ab188>,
#  'monument': <gensim.models.keyedvectors.Vocab at 0x201510ab1c8>,
#  'tribute': <gensim.models.keyedvectors.Vocab at 0x201510ab208>,
#  'today': <gensim.models.keyedvectors.Vocab at 0x201510ab248>,
#  'know': <gensim.models.keyedvectors.Vocab at 0x201510ab288>,
#  '``': <gensim.models.keyedvectors.Vocab at 0x201510ab2c8>,
#  'taj': <gensim.models.keyedvectors.Vocab at 0x201510ab308>,
#  "''": <gensim.models.keyedvectors.Vocab at 0x201510ab348>,
#  'construction': <gensim.models.keyedvectors.Vocab at 0x201510ab388>,
#  'started': <gensim.models.keyedvectors.Vocab at 0x201510ab3c8>,
#  'year': <gensim.models.keyedvectors.Vocab at 0x201510ab408>,
#  'masons': <gensim.models.keyedvectors.Vocab at 0x201510ab448>,
#  'stonecutters': <gensim.models.keyedvectors.Vocab at 0x201510ab488>,
#  'inlayers': <gensim.models.keyedvectors.Vocab at 0x201510ab4c8>,
#  'carvers': <gensim.models.keyedvectors.Vocab at 0x201510ab508>,
#  'painters': <gensim.models.keyedvectors.Vocab at 0x201510ab548>,
#  'calligraphers': <gensim.models.keyedvectors.Vocab at 0x201510ab588>,
#  'dome-builders': <gensim.models.keyedvectors.Vocab at 0x201510ab5c8>,
#  'artisans': <gensim.models.keyedvectors.Vocab at 0x201510ab608>,
#  'requisitioned': <gensim.models.keyedvectors.Vocab at 0x201510ab648>,
#  'whole': <gensim.models.keyedvectors.Vocab at 0x201510ab688>,
#  'empire': <gensim.models.keyedvectors.Vocab at 0x201510ab6c8>,
#  'also': <gensim.models.keyedvectors.Vocab at 0x201510ab708>,
#  'central': <gensim.models.keyedvectors.Vocab at 0x201510ab748>,
#  'asia': <gensim.models.keyedvectors.Vocab at 0x201510ab788>,
#  'iran': <gensim.models.keyedvectors.Vocab at 0x201510ab7c8>,
#  'took': <gensim.models.keyedvectors.Vocab at 0x201510ab808>,
#  'approximately': <gensim.models.keyedvectors.Vocab at 0x201510ab848>,
#  'years': <gensim.models.keyedvectors.Vocab at 0x201510ab888>,
#  'build': <gensim.models.keyedvectors.Vocab at 0x201510ab8c8>,
#  'see': <gensim.models.keyedvectors.Vocab at 0x201510ab908>,
#  'epitome': <gensim.models.keyedvectors.Vocab at 0x201510ab948>,
#  'love': <gensim.models.keyedvectors.Vocab at 0x201510ab988>,
#  'made': <gensim.models.keyedvectors.Vocab at 0x201510ab9c8>,
#  'use': <gensim.models.keyedvectors.Vocab at 0x201510aba08>,
#  'services': <gensim.models.keyedvectors.Vocab at 0x201510aba48>,
#  'laborers': <gensim.models.keyedvectors.Vocab at 0x201510aba88>,
#  'elephants': <gensim.models.keyedvectors.Vocab at 0x201510abac8>,
#  'entirely': <gensim.models.keyedvectors.Vocab at 0x201510abb08>,
#  'white': <gensim.models.keyedvectors.Vocab at 0x201510abb48>,
#  'marble': <gensim.models.keyedvectors.Vocab at 0x201510abb88>,
#  'brought': <gensim.models.keyedvectors.Vocab at 0x201510abbc8>,
#  'india': <gensim.models.keyedvectors.Vocab at 0x201510abc08>,
#  'expenditure': <gensim.models.keyedvectors.Vocab at 0x201510abc48>,
#  'million': <gensim.models.keyedvectors.Vocab at 0x201510abc88>,
#  'rupees': <gensim.models.keyedvectors.Vocab at 0x201510abcc8>,
#  'finally': <gensim.models.keyedvectors.Vocab at 0x201510abd08>,
#  'completed': <gensim.models.keyedvectors.Vocab at 0x201510abd48>,
#  'soon': <gensim.models.keyedvectors.Vocab at 0x201510abd88>,
#  'completion': <gensim.models.keyedvectors.Vocab at 0x201510abdc8>,
#  'deposed': <gensim.models.keyedvectors.Vocab at 0x201510abe08>,
#  'son': <gensim.models.keyedvectors.Vocab at 0x201510abe48>,
#  'aurangzeb': <gensim.models.keyedvectors.Vocab at 0x201510abe88>,
#  'put': <gensim.models.keyedvectors.Vocab at 0x201510abec8>,
#  'house': <gensim.models.keyedvectors.Vocab at 0x201510abf08>,
#  'arrest': <gensim.models.keyedvectors.Vocab at 0x201510abf48>,
#  'nearby': <gensim.models.keyedvectors.Vocab at 0x201510abf88>,
#  'agra': <gensim.models.keyedvectors.Vocab at 0x201510abfc8>,
#  'fort': <gensim.models.keyedvectors.Vocab at 0x201510b3048>,
#  'lies': <gensim.models.keyedvectors.Vocab at 0x201510b30c8>,
#  'entombed': <gensim.models.keyedvectors.Vocab at 0x201510b3148>,
#  'mausoleum': <gensim.models.keyedvectors.Vocab at 0x201510b3088>,
#  'along': <gensim.models.keyedvectors.Vocab at 0x201510b31c8>,
#  'moving': <gensim.models.keyedvectors.Vocab at 0x201510b3108>,
#  'history': <gensim.models.keyedvectors.Vocab at 0x201510b3248>,
#  'end': <gensim.models.keyedvectors.Vocab at 0x201510b3188>,
#  'century': <gensim.models.keyedvectors.Vocab at 0x201510b32c8>,
#  'british': <gensim.models.keyedvectors.Vocab at 0x201510b3208>,
#  'viceroy': <gensim.models.keyedvectors.Vocab at 0x201510b3348>,
#  'lord': <gensim.models.keyedvectors.Vocab at 0x201510b3288>,
#  'curzon': <gensim.models.keyedvectors.Vocab at 0x201510b33c8>,
#  'ordered': <gensim.models.keyedvectors.Vocab at 0x201510b3308>,
#  'sweeping': <gensim.models.keyedvectors.Vocab at 0x201510b3448>,
#  'restoration': <gensim.models.keyedvectors.Vocab at 0x201510b3388>,
#  'project': <gensim.models.keyedvectors.Vocab at 0x201510b34c8>,
#  'measure': <gensim.models.keyedvectors.Vocab at 0x201510b3408>,
#  'restore': <gensim.models.keyedvectors.Vocab at 0x201510b3548>,
#  'lost': <gensim.models.keyedvectors.Vocab at 0x201510b3488>,
#  'indian': <gensim.models.keyedvectors.Vocab at 0x201510b35c8>,
#  'rebellion': <gensim.models.keyedvectors.Vocab at 0x201510b3508>,
#  ':': <gensim.models.keyedvectors.Vocab at 0x201510b3648>,
#  'blemished': <gensim.models.keyedvectors.Vocab at 0x201510b3588>,
#  'soldiers': <gensim.models.keyedvectors.Vocab at 0x201510b36c8>,
#  'government': <gensim.models.keyedvectors.Vocab at 0x201510b3608>,
#  'officials': <gensim.models.keyedvectors.Vocab at 0x201510b3748>,
#  'deprived': <gensim.models.keyedvectors.Vocab at 0x201510b3688>,
#  'immaculate': <gensim.models.keyedvectors.Vocab at 0x201510b37c8>,
#  'beauty': <gensim.models.keyedvectors.Vocab at 0x201510b3708>,
#  'chiseling': <gensim.models.keyedvectors.Vocab at 0x201510b3848>,
#  'precious': <gensim.models.keyedvectors.Vocab at 0x201510b3788>,
#  'stones': <gensim.models.keyedvectors.Vocab at 0x201510b38c8>,
#  'lapis': <gensim.models.keyedvectors.Vocab at 0x201510b3808>,
#  'lazuli': <gensim.models.keyedvectors.Vocab at 0x201510b3948>,
#  'walls': <gensim.models.keyedvectors.Vocab at 0x201510b3888>,
#  'style': <gensim.models.keyedvectors.Vocab at 0x201510b39c8>,
#  'lawns': <gensim.models.keyedvectors.Vocab at 0x201510b3908>,
#  'adding': <gensim.models.keyedvectors.Vocab at 0x201510b3a48>,
#  'remodeled': <gensim.models.keyedvectors.Vocab at 0x201510b3988>,
#  'around': <gensim.models.keyedvectors.Vocab at 0x201510b3ac8>,
#  'time': <gensim.models.keyedvectors.Vocab at 0x201510b3a08>,
#  'despite': <gensim.models.keyedvectors.Vocab at 0x201510b3b48>,
#  'prevailing': <gensim.models.keyedvectors.Vocab at 0x201510b3a88>,
#  'controversies': <gensim.models.keyedvectors.Vocab at 0x201510b3bc8>,
#  'past': <gensim.models.keyedvectors.Vocab at 0x201510b3b08>,
#  'present': <gensim.models.keyedvectors.Vocab at 0x201510b3c48>,
#  'threats': <gensim.models.keyedvectors.Vocab at 0x201510b3b88>,
#  'indo-pak': <gensim.models.keyedvectors.Vocab at 0x201510b3cc8>,
#  'war': <gensim.models.keyedvectors.Vocab at 0x201510b3c08>,
#  'environmental': <gensim.models.keyedvectors.Vocab at 0x201510b3d48>,
#  'pollution': <gensim.models.keyedvectors.Vocab at 0x201510b3c88>,
#  'continuous': <gensim.models.keyedvectors.Vocab at 0x201510b3dc8>,
#  'shine': <gensim.models.keyedvectors.Vocab at 0x201510b3d08>,
#  'attract': <gensim.models.keyedvectors.Vocab at 0x201510b3e48>,
#  'people': <gensim.models.keyedvectors.Vocab at 0x201510b3d88>,
#  'world': <gensim.models.keyedvectors.Vocab at 0x201510b3ec8>}

# %%
#finding the word vectors
vector = model.wv['started']

# %%
vector
# Out:
# array([-0.00379521,  0.00332229,  0.00011608, -0.00145855, -0.00477365,
#         0.00065065,  0.00341666, -0.00433526, -0.00335862, -0.00454379,
#        -0.00356569, -0.00253625,  0.00102142,  0.00190609,  0.00114152,
#        -0.0044442 , -0.00285224,  0.00146307, -0.00253126,  0.00058935,
#         0.00496228, -0.00468632,  0.00355511,  0.00281439, -0.00421372,
#        -0.0024266 , -0.00165703,  0.00176254,  0.00058418,  0.00431856,
#        -0.00238489,  0.00074949, -0.00372244,  0.00356759, -0.00317222,
#        -0.00446263,  0.00360401, -0.00344692,  0.00476821, -0.00316547,
#         0.00311838, -0.0022838 , -0.00282053,  0.00061034, -0.0039073 ,
#         0.0004035 , -0.00172946,  0.00486761, -0.00433259,  0.00131797,
#         0.0045766 , -0.00040953, -0.00323499,  0.00358612,  0.00167256,
#         0.00481803,  0.00229793, -0.00072476,  0.00153334, -0.00183453,
#         0.00450621,  0.00486771, -0.00425967, -0.00064777,  0.00386517,
#        -0.00033521,  0.00293579, -0.00047928,  0.00352211,  0.00426564,
#         0.00297505,  0.00018437, -0.00342435,  0.0035189 , -0.00047025,
#        -0.00286712,  0.00125732, -0.00398379,  0.00287381,  0.00209176,
#        -0.00371114, -0.00069923, -0.004436  , -0.00146888, -0.0005036 ,
#        -0.00493992, -0.00340554, -0.00158167,  0.00112593, -0.00082577,
#         0.00087337,  0.00235421, -0.00129837,  0.00405403,  0.00261271,
#        -0.00010487, -0.00116381, -0.00270152, -0.00417076, -0.0028804 ],
#       dtype=float32)

# %%
#find out the most similar words
similar = model.wv.most_similar('memory')

# %%
similar
# Out:
# [('see', 0.2673841416835785),
#  ('aurangzeb', 0.25759902596473694),
#  ('environmental', 0.24952109158039093),
#  ('th', 0.249161496758461),
#  ('past', 0.21990394592285156),
#  ('artisans', 0.1830122172832489),
#  ('painters', 0.17645886540412903),
#  ('white', 0.17238633334636688),
#  ('calligraphers', 0.166988804936409),
#  ('masons', 0.16593024134635925)]
